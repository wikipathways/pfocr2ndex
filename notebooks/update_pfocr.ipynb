# %%
# %load_ext lab_black

# %% [markdown]
# Look at using this for jupyterlab-connect on macOS:
# ```
# caffeinate -i -s /usr/bin/ssh nixos
# ```
#
# or maybe:
# ```
# caffeinate -i -s /usr/local/bin/mosh nixos
# ```
#
# or maybe:
# ```
# caffeinate -i -s /Users/andersriutta/jupyterlab-connect/bin/jupyterlab-connect nixos:Documents/pfocr2ndex
# ```

# %%
import json
import ndex2.client
import os
import numpy as np
import pandas as pd
from pathlib import Path
import pprint

from caching import cache_from_dropbox

# %%
pp = pprint.PrettyPrinter(indent=4)

# %%
import getpass

ndex_user = os.environ.get("NDEX_USER")
ndex_pwd = os.environ.get("NDEX_PWD")

if not ndex_user:
    print("Please enter your NDEx username:")
    ndex_user = input()

if not ndex_pwd:
    print("Please enter your NDEx password:")
    ndex_pwd = getpass.getpass()

networkset_ids_by_name = dict()

if ndex_user == "wikipathways":
    # for prod
    ndex_url = "http://www.ndexbio.org"
    networkset_ids_by_name[
        "Published Pathway Figures - Analysis Set"
    ] = "85034b42-de8a-11ea-99da-0ac135e8bacf"
    networkset_ids_by_name[
        "WikiPathways Collection - Homo sapiens"
    ] = "453c1c63-5c10-11e9-9f06-0ac135e8bacf"
    networkset_ids_by_name[
        "CPTAC Cancer Hallmark Networks"
    ] = "9541cc61-4cf0-11e9-9f06-0ac135e8bacf"
elif ndex_user:
    # for test/dev
    ndex_url = "http://test.ndexbio.org"
    networkset_ids_by_name[
        "Published Pathway Figures - Analysis Set"
    ] = "8970df33-d6bd-11ea-9101-0660b7976219"
    networkset_ids_by_name[
        "wikipathways-gpml-Homo_sapiens"
    ] = "b44b7ca7-4da1-11e9-9fc6-0660b7976219"

print(f"Running as {ndex_user} on {ndex_url}")
# Out:
# Please enter your NDEx username:
#  wikipathways
# Please enter your NDEx password:
#  ······
# Running as wikipathways on http://www.ndexbio.org

# %% [markdown]
# ## NDEx
#
# Let's get the current user's info from NDEx to check that we can connect correctly:

# %%
anon_ndex = ndex2.client.Ndex2(ndex_url)

# %%
anon_ndex.get_user_by_username(ndex_user)
# Out:
# {'properties': {},
#  'isIndividual': True,
#  'userName': 'wikipathways',
#  'isVerified': True,
#  'firstName': 'WikiPathways',
#  'lastName': 'Project',
#  'image': 'https://upload.wikimedia.org/wikipedia/commons/8/83/Wplogo_with_text_500.png',
#  'website': 'https://www.wikipathways.org',
#  'description': '<p></p><h6>Welcome to the NDEx repository for <a href="https://wikipathways.org" target="">WikiPathways</a>. Here we provide network versions of our curated and approved pathway content. <br/>All our content is freely available under the CC0 waiver. Feel free to clone, download, reuse, adapt and publish. Here\'s <a href="https://www.wikipathways.org/index.php/How_to_cite_WikiPathways" target="">how to cite us</a>. <br/></h6><h6><b>For WikiPathways Authors</b>: to add new WikiPathways models or edit the original existing ones, please visit <a href="https://wikipathways.org">our website.</a> <br/></h6>',
#  'externalId': '363f49e0-4cf0-11e9-9f06-0ac135e8bacf',
#  'isDeleted': False,
#  'modificationTime': 1597541613501,
#  'creationTime': 1553293019749}

# %% [markdown]
# Now we'll log in as the current user:

# %%
my_ndex = ndex2.client.Ndex2(ndex_url, ndex_user, ndex_pwd)

# %% [markdown]
# And we'll get the info for the PFOCR network set:

# %%
pfocr_networkset_id = networkset_ids_by_name["Published Pathway Figures - Analysis Set"]

pfocr_networkset_data = my_ndex.get_networkset(pfocr_networkset_id)
pfocr_networkset_data.keys()
# Out:
# dict_keys(['name', 'description', 'ownerId', 'networks', 'showcased', 'properties', 'externalId', 'isDeleted', 'modificationTime', 'creationTime'])

# %%
len(pfocr_networkset_data["networks"])
# Out:
# 32263

# %%
sample_network = my_ndex.get_network_summary(pfocr_networkset_data["networks"][0])
sample_network.keys()
# Out:
# dict_keys(['ownerUUID', 'isReadOnly', 'subnetworkIds', 'isValid', 'warnings', 'isShowcase', 'isCertified', 'indexLevel', 'hasLayout', 'hasSample', 'cxFileSize', 'cx2FileSize', 'visibility', 'nodeCount', 'completed', 'edgeCount', 'owner', 'version', 'description', 'name', 'properties', 'externalId', 'isDeleted', 'modificationTime', 'creationTime'])

# %% [markdown]
# I think we can't search for network by `pfocr_id` (`figid`) because we didn't specify these networks should be indexed:
# ```
# Visibility: Public (not searchable)
# ```
#
# Was this just for test.ndexbio.org or for production too? I think we only index the network set, not the individual networks contained.
#
# How should we find `pfocr_id` by `network_id`? What does `include_groups` mean?

# %%
my_ndex.search_networks(
    search_string="PMC5868458__fphys-09-00170-g0003.jpg",
    account_name=ndex_user,
    start=0,
    size=100,
    include_groups=True,
)
# Out:
# {'numFound': 0, 'start': 0, 'networks': []}

# %% [markdown]
# ## Map `pfocr_id` to `network_id`

# %% [markdown]
# Let's get the mappings from `pfocr_id` (`figid`) to `network_id`:
#
# TODO: is there a better endpoint to call for this now? Maybe look into the following:
# >Get Network Summaries By UUIDs
# >
# >/batch/network/summary?accesskey={accessKey}
#
# https://home.ndexbio.org/using-the-ndex-server-api/

# %%
cached_pfocr_id_to_network_id_filepath = (
    f"../data/{ndex_user}_pfocr_id_to_network_id.json"
)

pfocr_id_to_network_id = dict()

cached_pfocr_id_to_network_id_f = (
    Path(cached_pfocr_id_to_network_id_filepath).expanduser().resolve()
)

if cached_pfocr_id_to_network_id_f.exists():
    with open(cached_pfocr_id_to_network_id_filepath, "r") as f:
        pfocr_id_to_network_id = json.load(f)
else:
    for network_id in pfocr_networkset_data["networks"]:
        network_summary = my_ndex.get_network_summary(network_id)
        properties = network_summary["properties"]

        pfocr_id = next(p for p in properties if p["predicateString"] == "pfocr_id")[
            "value"
        ]

        if pfocr_id != network_summary["name"]:
            raise Exception(
                f"Expected pfocr_id {pfocr_id} to equal network_summary['name'] {network_summary['name']}"
            )

        if not pfocr_id in pfocr_id_to_network_id:
            pfocr_id_to_network_id[pfocr_id] = network_id
        else:
            raise Exception(
                f"pfocr_id_to_network_id[{pfocr_id}] already set: {pfocr_id_to_network_id[pfocr_id]}"
            )

    with open(cached_pfocr_id_to_network_id_filepath, "w") as f:
        json.dump(pfocr_id_to_network_id, f)

# %%
list(pfocr_id_to_network_id.items())[0]
# Out:
# ('PMC6372626__41467_2019_8576_Fig6_HTML.jpg',
#  '0626a9a9-df0c-11ea-99da-0ac135e8bacf')

# %% [markdown]
# ## Load PFOCR Data

# %%
import pandas as pd
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
from rpy2.robjects import pandas2ri

from rpy2.robjects.conversion import localconverter

pandas2ri.activate()
base = importr("base")
readRDS = ro.r["readRDS"]
# Out:
# /nix/store/1p75vcb4phw4x10rk6jzm00b3jcccz40-python3-3.8.7-env/lib/python3.8/site-packages/rpy2/robjects/vectors.py:980: UserWarning: R object inheriting from "POSIXct" but without attribute "tzone".
#   warnings.warn('R object inheriting from "POSIXct" but without '

# %% [markdown]
# ### figures

# %%
analysis_set_figure_ids_url = (
    "https://www.dropbox.com/s/r7kc2hwzou3r2gm/analysis_set_figure_ids.tsv?dl=1"
)
analysis_set_figure_ids_f = Path(
    "~/Dropbox (Gladstone)/Documents/PFOCR_25Years/analysis_set_figure_ids.tsv"
).expanduser()
cache_from_dropbox(url=analysis_set_figure_ids_url, dest=analysis_set_figure_ids_f)

analysis_set_figure_ids = set()
with open(analysis_set_figure_ids_f, "r") as f:
    for line in f.read().splitlines():
        analysis_set_figure_ids.add(line)

len(analysis_set_figure_ids)
# Out:
# /home/ariutta/Dropbox (Gladstone)/Documents/PFOCR_25Years/analysis_set_figure_ids.tsv exists. Assuming already cached.
# 32279

# %%
pfocr_figures_rds_url = (
    "https://www.dropbox.com/s/n5j6vrd1v93ve05/pfocr_figures.rds?dl=1"
)
pfocr_figures_f = "~/Dropbox (Gladstone)/Documents/PFOCR_25Years/pfocr_figures.rds"
cache_from_dropbox(url=pfocr_figures_rds_url, dest=pfocr_figures_f)
pfocr_figures_rdf = readRDS(pfocr_figures_f)
with localconverter(ro.default_converter + pandas2ri.converter):
    pfocr_figures_df = (
        ro.conversion.rpy2py(pfocr_figures_rdf)
        .rename(
            columns={
                "figid": "pfocr_id",
                "year": "publication_year",
                "number": "figure_number",
                "figtitle": "figure_title",
                "papertitle": "paper_title",
            }
        )
        .sort_values(["publication_year", "pmcid", "pfocr_id"])
    )

pfocr_figures_df["paper_link"] = (
    "https://www.ncbi.nlm.nih.gov/pmc/articles/" + pfocr_figures_df["pmcid"]
)

# pfocr_figures_df["figure_page_url"] = (
#    "https://www.ncbi.nlm.nih.gov/pmc/articles/"
#    + pfocr_figures_df["pmcid"]
#    + "/bin/"
#    + pfocr_figures_df["filename"]
# )

pfocr_figures_df["figure_page_url"] = (
    "https://www.ncbi.nlm.nih.gov" + pfocr_figures_df["figlink"]
)

pfocr_figures_df["figure_thumbnail_url"] = (
    "https://www.ncbi.nlm.nih.gov/pmc/articles/"
    + pfocr_figures_df["pmcid"]
    + "/bin/"
    + pfocr_figures_df["filename"]
)


pfocr_figures_df.head(2)
# Out:
# ~/Dropbox (Gladstone)/Documents/PFOCR_25Years/pfocr_figures.rds exists. Assuming already cached.
#                             pfocr_id       pmcid           filename  \
# 52325  PMC6134364__GE-4-357-g005.jpg  PMC6134364  GE-4-357-g005.jpg
# 32576   PMC6138031__GE-5-01-g002.jpg  PMC6138031   GE-5-01-g002.jpg
#
#       publication_year  pathway_score  pmc_ranked_result_index  \
# 52325             1995       0.882552                   115615
# 32576             1995       0.953649                   120261
#
#                                      figlink  \
# 52325  /pmc/articles/PMC6134364/figure/fig5/
# 32576  /pmc/articles/PMC6138031/figure/fig2/
#
#                                            source_f type.man  automl_index  \
# 52325  ../data/images/PMC6134364__GE-4-357-g005.jpg     None         42272
# 32576   ../data/images/PMC6138031__GE-5-01-g002.jpg     None         12632
#
#                                                  reftext  \
# 52325      Joe B. Harford. Gene Expr. 1995;4(6):357-367.
# 32576  Kimberly C. Gilmour, et al. Gene Expr. 1995;5(...
#
#                                              paper_title  \
# 52325  Translation-Targeted Therapeutics for Viral Di...
# 32576  Signal Transduction and Activation of Gene Tra...
#
#                                             figure_title figure_number  \
# 52325                                        PKR pathway        FIG. 5
# 32576  Illustrative model of the IFN signal transduct...        FIG. 2
#
#                                                  caption      organism  \
# 52325  The PKR pathway. Double-stranded RNA (dsRNA) r...  Homo sapiens
# 32576  Illustrative model of the IFN signal transduct...  Homo sapiens
#
#                                               paper_link  \
# 52325  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 32576  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
#
#                                          figure_page_url  \
# 52325  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 32576  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
#
#                                     figure_thumbnail_url
# 52325  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 32576  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...

# %%
print(len(analysis_set_figure_ids))
print(len(set(pfocr_figures_df["pfocr_id"]) - analysis_set_figure_ids))
print(len(analysis_set_figure_ids - set(pfocr_figures_df["pfocr_id"])))
# Out:
# 32279
# 32364
# 0

# %% [markdown]
# Add column `network_id` (for NDEx):

# %%
pfocr_figures_df["network_id"] = pfocr_figures_df["pfocr_id"].apply(
    lambda pfocr_id: pfocr_id_to_network_id.get(pfocr_id, None)
)
pfocr_figures_df[pfocr_figures_df["network_id"].notnull()].head(2)
# Out:
#                             pfocr_id       pmcid           filename  \
# 52325  PMC6134364__GE-4-357-g005.jpg  PMC6134364  GE-4-357-g005.jpg
# 32576   PMC6138031__GE-5-01-g002.jpg  PMC6138031   GE-5-01-g002.jpg
#
#       publication_year  pathway_score  pmc_ranked_result_index  \
# 52325             1995       0.882552                   115615
# 32576             1995       0.953649                   120261
#
#                                      figlink  \
# 52325  /pmc/articles/PMC6134364/figure/fig5/
# 32576  /pmc/articles/PMC6138031/figure/fig2/
#
#                                            source_f type.man  automl_index  \
# 52325  ../data/images/PMC6134364__GE-4-357-g005.jpg     None         42272
# 32576   ../data/images/PMC6138031__GE-5-01-g002.jpg     None         12632
#
#                                                  reftext  \
# 52325      Joe B. Harford. Gene Expr. 1995;4(6):357-367.
# 32576  Kimberly C. Gilmour, et al. Gene Expr. 1995;5(...
#
#                                              paper_title  \
# 52325  Translation-Targeted Therapeutics for Viral Di...
# 32576  Signal Transduction and Activation of Gene Tra...
#
#                                             figure_title figure_number  \
# 52325                                        PKR pathway        FIG. 5
# 32576  Illustrative model of the IFN signal transduct...        FIG. 2
#
#                                                  caption      organism  \
# 52325  The PKR pathway. Double-stranded RNA (dsRNA) r...  Homo sapiens
# 32576  Illustrative model of the IFN signal transduct...  Homo sapiens
#
#                                               paper_link  \
# 52325  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 32576  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
#
#                                          figure_page_url  \
# 52325  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 32576  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
#
#                                     figure_thumbnail_url  \
# 52325  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 32576  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
#
#                                  network_id
# 52325  a6088798-df17-11ea-99da-0ac135e8bacf
# 32576  994fae28-deee-11ea-99da-0ac135e8bacf

# %% [markdown]
# Let's add some columns we know we'll use

# %%
pfocr_figures_df[
    "methods"
] = "Pathway Figure OCR, https://www.biorxiv.org/content/10.1101/2020.05.29.124503v1.full "

pfocr_figures_df["rights"] = "Waiver-No rights reserved (CC0)"

pfocr_figures_df["network_type"] = "pathway"

## the following takes too much memory
# pfocr_df["reference"] = (
#    pfocr_df["reftext"].astype("str")
#    + "<b>"
#    + pfocr_df["paper_title"].astype("str")
#    + '</b> <a href="'
#    + pfocr_df["paper_link"].astype("str")
#    + 'target="_blank">'
#    + pfocr_df["paper_link"].astype("str")
#    + "</a>"
# )

# %% [markdown]
# ### Pathway Disease Associations
#
# Alex did a gene enrichment analysis on the PFOCR data to get pathway-disease associations. He provided the data [here](https://github.com/wikipathways/pathway-figure-ocr/issues/16#issuecomment-611684935).

# %%
pathway_disease_url = (
    "https://www.dropbox.com/s/vgazcxdq4wsl5yk/pfocr_disease_map.tsv?dl=0"
)

# %%
pfocr_disease_map_f = "../data/pfocr_disease_map.tsv"
cache_from_dropbox(url=pathway_disease_url, dest=pfocr_disease_map_f)
# Out:
# ../data/pfocr_disease_map.tsv exists. Assuming already cached.

# %%
pfocr_disease_df = pd.read_csv(pfocr_disease_map_f, sep="\t").rename(
    columns={"figid": "pfocr_id"}
)
pfocr_disease_df
# Out:
#                           pfocr_id                                    terms  \
# 0      PMC100008__mb2411709009.jpg                                   Cancer
# 1      PMC100008__mb2411709009.jpg               Primary hyperaldosteronism
# 2      PMC100008__mb2411709009.jpg                              Lung cancer
# 3      PMC100008__mb2411709009.jpg                          Noonan syndrome
# 4          PMC101242__gkf20707.jpg                            Breast cancer
# ...                            ...                                      ...
# 72877   PMC99889__mb2110211013.jpg                                   Cancer
# 72878   PMC99889__mb2110211013.jpg                           Cardiomyopathy
# 72879   PMC99889__mb2110211013.jpg                              Lung cancer
# 72880   PMC99889__mb2110211013.jpg                          Noonan syndrome
# 72881   PMC99957__mb2310813001.jpg  Autoimmune lymphoproliferative syndrome
#
#                doid
# 0          DOID:162
# 1        DOID:12252
# 2         DOID:1324
# 3         DOID:3490
# 4         DOID:1612
# ...             ...
# 72877      DOID:162
# 72878  DOID:0050700
# 72879     DOID:1324
# 72880     DOID:3490
# 72881     DOID:6688
#
# [72882 rows x 3 columns]

# %%
disease_pfocr_ids = set(pfocr_disease_df["pfocr_id"])
len(disease_pfocr_ids)
# Out:
# 23331

# %% [markdown]
# ### Genes

# %% [raw]
# pfocr_genes_rds_url = "https://www.dropbox.com/s/alf7auvxve36oer/pfocr_genes.rds?dl=1"
# pfocr_genes_f = "~/Dropbox (Gladstone)/Documents/PFOCR_25Years/pfocr_genes.rds"
# cache_from_dropbox(url=pfocr_genes_rds_url, dest=pfocr_genes_f)
# pfocr_genes_rdf = readRDS(pfocr_genes_f)
# with localconverter(ro.default_converter + pandas2ri.converter):
#     pfocr_genes_df = (ro.conversion.rpy2py(pfocr_genes_rdf)).rename(columns={"figid": "pfocr_id"}).sort_values(["pmcid", "pfocr_id", "entrez"])
#
# pfocr_genes_df.head(2)

# %% [markdown]
# ### Merge

# %% [raw]
# # merge the dfs to get pfocr analysis set
# pfocr_df = (
#     (
#         pfocr_figures_df.join(
#             # dropping column pmcid because it already exists in pfocr_figures_df
#             pfocr_genes_df.drop(columns=["pmcid"]).set_index("pfocr_id"),
#             on="pfocr_id",
#             how="inner",
#         )
#     )
#     .sort_values(["publication_year", "pmcid", "pfocr_id", "entrez"])
#     .reset_index(drop=True)
# )
#
# pfocr_df.head()

# %% [raw]
# list(pfocr_df.columns)

# %% [markdown]
# ### Compare sets: PFOCR networks already on NDEx vs. analysis set

# %%
pfocr_on_ndex_df = pfocr_figures_df[pfocr_figures_df["network_id"].notnull()]
print(len(analysis_set_figure_ids))
print(len(set(pfocr_on_ndex_df["pfocr_id"])))
print(len(set(pfocr_on_ndex_df["pfocr_id"]).intersection(analysis_set_figure_ids)))
print(len(set(pfocr_on_ndex_df["pfocr_id"]) - analysis_set_figure_ids))
print(len(analysis_set_figure_ids - set(pfocr_on_ndex_df["pfocr_id"])))
# Out:
# 32279
# 32263
# 32263
# 0
# 16

# %% [markdown]
# ### What predicateStrings are we using on NDEx?

# %%
properties_by_predicate_string = dict()
for i, row in (
    pfocr_figures_df[pfocr_figures_df["network_id"].notnull()].head(1000).iterrows()
):
    network_id = row["network_id"]
    pfocr_id = row["pfocr_id"]

    network_properties = my_ndex.get_network_summary(network_id)["properties"]
    for network_property in network_properties:
        predicate_string = network_property["predicateString"]
        data_type = network_property["dataType"]
        sub_network_id = network_property["subNetworkId"]
        if not predicate_string in properties_by_predicate_string:
            properties_by_predicate_string[predicate_string] = {
                "subNetworkId": set(),
                "dataType": set(),
            }
        properties_by_predicate_string[predicate_string]["subNetworkId"].add(
            sub_network_id
        )
        properties_by_predicate_string[predicate_string]["dataType"].add(data_type)

# pp.pprint(properties_by_predicate_string)

network_properties_template = list()
network_property_data_types_by_predicate_string = dict()
for k, v in properties_by_predicate_string.items():
    v["predicateString"] = k
    v["value"] = ""

    sub_network_ids = list(v["subNetworkId"])
    if len(sub_network_ids) > 1:
        raise Exception(f"{k} has more than one subNetworkId")
    else:
        v["subNetworkId"] = sub_network_ids[0]

    data_types = list(v["dataType"])
    if len(data_types) > 1:
        raise Exception(f"{k} has more than one dataType")
    else:
        v["dataType"] = data_types[0]

    network_property_data_types_by_predicate_string[k] = data_types[0]

    network_properties_template.append(v)
pp.pprint(network_property_data_types_by_predicate_string)
# Out:
# {   'figureLink': 'string',
#     'figureNumber': 'string',
#     'figureTitle': 'string',
#     'methods': 'string',
#     'networkType': 'string',
#     'organism': 'string',
#     'paperLink': 'string',
#     'paperTitle': 'string',
#     'pfocrId': 'string',
#     'pmcId': 'string',
#     'publicationYear': 'string',
#     'reference': 'string',
#     'rights': 'string'}

# %% [markdown]
# ### Remove networks from PFOCR networkset on NDEx if they are not in the analysis set

# %%
def remove_network_id(network_id):
    pfocr_figures_df.loc[
        (
            pfocr_figures_df["network_id"] == network_id,
            "network_id",
        )
    ] = None

    del pfocr_id_to_network_id[pfocr_id]
    with open(cached_pfocr_id_to_network_id_filepath, "w") as f:
        json.dump(pfocr_id_to_network_id, f)

    pfocr_on_ndex_df = pfocr_figures_df[pfocr_figures_df["network_id"].notnull()]

    pfocr_df.loc[
        (
            pfocr_df["network_id"] == network_id,
            "network_id",
        )
    ] = None


for pfocr_id in (
    set(pfocr_figures_df[pfocr_figures_df["network_id"].notnull()]["pfocr_id"])
    - analysis_set_figure_ids
):
    network_id = pfocr_id_to_network_id[pfocr_id]

    my_ndex.set_read_only(network_id, False)
    my_ndex.delete_network(network_id)

    remove_network_id(network_id)

# %% [markdown]
# ### Update properties of remaining networks to match `pfocr_figures_df`
#
# Still need to add networks from analysis set if they are not on NDEx.

# %%
import time
import math

data_type_by_predicate_string = {
    "disease": "string",
    "figureLink": "string",
    "figureNumber": "string",
    "figureTitle": "string",
    "methods": "string",
    "networkType": "string",
    "organism": "string",
    "paperLink": "string",
    "paperTitle": "string",
    "pfocrId": "string",
    "pmcId": "string",
    "publicationYear": "string",
    "reference": "string",
    "rights": "string",
}

# disease and reference don't come directly from a
# pfocr_figures_df column, so we don't include them
# here. We need to use custom logic for them.
column_name_by_predicate_string = {
    # note the difference:
    #     figure_thumbnail_url: URL to the actual JPG of the thumbnail
    #     figure_page_url: URL to the HTML page for the figure
    "figureLink": "figure_page_url",
    "figureNumber": "figure_number",
    "figureTitle": "figure_title",
    "methods": "methods",
    "networkType": "network_type",
    "organism": "organism",
    "paperLink": "paper_link",
    "paperTitle": "paper_title",
    "pfocrId": "pfocr_id",
    "pmcId": "pmcid",
    "publicationYear": "publication_year",
    "rights": "rights",
}

column_names = column_name_by_predicate_string.values()

log_file_path = "./update_pfocr.log"

def update_networks(
    my_ndex,
    remaining_pfocr_figures_df,
    consecutive_fails_count_limit=10,
    no_progress_iterations_count_limit=3,
    completed=set(),
    no_progress_iterations_count=0,
    iteration=0
):
    msg = f"attempt {no_progress_iterations_count + 1} of {no_progress_iterations_count_limit + 1}"
    print(msg)
    
    # overwrite the first time
    with open(log_file_path, "w" if (iteration == 0) else "a") as f:
        f.write(msg + "\n")
        
    consecutive_fails_count = 0
    initial_completed_count = len(completed)
    for i, pfocr_figures_row in remaining_pfocr_figures_df.iterrows():
        network_id = pfocr_figures_row["network_id"]
        pfocr_id = pfocr_figures_row["pfocr_id"]

        try:
            existing_network_properties = my_ndex.get_network_summary(network_id)["properties"]
        except Exception as e:
            with open(log_file_path, "a") as f:
                f.write(f"Can't get network_id {network_id}\n")
                f.write(e + "\n")
            print(f"Can't get network_id {network_id}")
            print(e)

            consecutive_fails_count += 1
            if consecutive_fails_count >= consecutive_fails_count_limit:
                raise Exception(f"Failed for too many. Stopping.")
            else:
                print(f"Skipping {network_id} and moving to next.")
                with open(log_file_path, "a") as f:
                    f.write(f"Skipping {network_id} and moving to next.\n")
                continue

        ###################
        # "auto" properties
        # -----------------
        # "Automatically" translated from dataframe column to network property via column_name_by_predicate_string.
        # Data type comes from data_type_by_predicate_string.
        ###################
        updated_network_properties = list()

        for predicate_string, column_name in column_name_by_predicate_string.items():
            data_type = data_type_by_predicate_string[predicate_string]

            if pfocr_figures_row[column_name] is None:
                print(
                    f"missing_column_name: {column_name} not found in pfocr_figures_row for {pfocr_id} / {network_id}"
                )
                missing_property = next(
                    (
                        x
                        for x in existing_network_properties
                        if x["predicateString"] == predicate_string
                    ),
                    None,
                )
                if missing_property:
                    # updated_network_properties.append(missing_property)
                    raise Exception(
                        f"{column_name} not found in pfocr_figures_row, BUT {predicate_string} was previously set on NDEx for {pfocr_id} / {network_id}"
                    )
            else:
                updated_network_properties.append(
                    {
                        "predicateString": predicate_string,
                        "value": pfocr_figures_row[column_name],
                        "dataType": data_type,
                        "subNetworkId": None,
                    }
                )

        ############
        # reference
        ############
        paper_title = pfocr_figures_row["paper_title"]
        paper_link = pfocr_figures_row["paper_link"]
        reftext = pfocr_figures_row["reftext"]
        updated_network_properties.append(
            {
                "predicateString": "reference",
                "value": f'{reftext} <b>{paper_title}</b> <a href="{paper_link}" target="_blank">{paper_link}</a>',
                "dataType": data_type_by_predicate_string["reference"],
                "subNetworkId": None,
            }
        )

        ##########
        # disease
        ##########
        # Here's an example what a disease property value should look like:
        # '<a href="https://identifiers.org/doid/DOID:332">ALS</a>, <a href="https://identifiers.org/doid/DOID:332">amyotrophic lateral sclerosis</a>'

        disease_links = list()
        for i, disease_row in pfocr_disease_df[
            pfocr_disease_df["pfocr_id"] == pfocr_id
        ][["terms", "doid"]].iterrows():
            term = disease_row["terms"]
            doid = disease_row["doid"]
            disease_links.append(
                f'<a href="https://identifiers.org/doid/{doid}">{term}</a>'
            )
        if len(disease_links) > 0:
            updated_network_properties.append(
                {
                    "predicateString": "disease",
                    "dataType": "string",
                    "value": ", ".join(disease_links),
                    "subNetworkId": None,
                }
            )

        try:
            my_ndex.set_read_only(network_id, False)

            # network profile
            caption = pfocr_figures_row["caption"]
            figure_thumbnail_url = pfocr_figures_row["figure_thumbnail_url"]
            description = f"""
<p>{caption}</p>
<p><img src="{figure_thumbnail_url}" style="width: 100%;"></p>
            """
            my_ndex.update_network_profile(
                network_id,
                {"name": pfocr_figures_row["figure_title"], "description": description},
            )

            # network properties
            my_ndex.set_network_properties(network_id, updated_network_properties)

            my_ndex.set_read_only(network_id, True)

            no_progress_iterations_count = 0
            consecutive_fails_count = 0
            completed.add(network_id)
            with open(log_file_path, "a") as f:
                f.write(f"success: {network_id}\n")
        except Exception as e:
            print(f"Failed for network_id {network_id}")
            print(e)
            with open(log_file_path, "a") as f:
                f.write(f"Failed for network_id {network_id}.\n")
                f.write(e + "\n")

            # Let's keep track of the count if we fail for multiple consecutive networks
            # within a single try (or retry) cycle.
            consecutive_fails_count += 1
            if consecutive_fails_count >= consecutive_fails_count_limit:
                print(f"Failed for {consecutive_fails_count} consecutive networks. Stopping.")
                raise e
            else:
                print(f"Skipping {network_id} and moving to next.")
                with open(log_file_path, "a") as f:
                    f.write(f"Skipping {network_id} and moving to next.\n")
                continue

    if len(set(remaining_pfocr_figures_df["network_id"]) - completed) == 0:
        print("All networks now updated.")
        return 0
    elif no_progress_iterations_count >= no_progress_iterations_count_limit:
        print(f"""
            We have tried/retried {no_progress_iterations_count} consecutive times without making any progress.
            We need to stop and take a look at why.
        """)
        return 1
    else:
        if len(completed) == initial_completed_count:
            # If we didn't make any progress in this try (or retry) cycle, wait before trying again.
            # Use exponential back off:
            # 7^0 x 5 = 5 min
            # 7^1 x 5 = 35 min
            # 7^2 x 5 = ~4 hrs
            # 7^3 x 5 = ~29 hrs

            backoff_base = 7
            initial_wait = 5  # minutes
            wait_sec = (
                math.pow(backoff_base, no_progress_iterations_count) * initial_wait * 60
            )
            print(f"waiting for {int(wait_sec / 60)} min before trying again")
            with open(log_file_path, "a") as f:
                f.write(f"waiting for {int(wait_sec / 60)} min before trying again.\n")
            time.sleep(wait_sec)

            # Let's keep track of how many times in a row our retries fail to make any progress.
            no_progress_iterations_count += 1

        remaining_pfocr_figures_df = pfocr_figures_df[
            pfocr_figures_df["network_id"].notnull()
            & (~pfocr_figures_df["network_id"].isin(completed))
        ]
        print(f'''
            Updated {len(completed) - initial_completed_count} networks this round for a total of {len(completed)} from all rounds,
            leaving {len(remaining_pfocr_figures_df)} networks remaining to be updated.
        ''')
        with open(log_file_path, "a") as f:
            f.write(f"Networks updated: {len(completed) - initial_completed_count} this round, {len(completed)} total, {len(remaining_pfocr_figures_df)} remaining.\n")

        return update_networks(
            my_ndex,
            remaining_pfocr_figures_df,
            consecutive_fails_count_limit,
            no_progress_iterations_count_limit,
            completed,
            no_progress_iterations_count,
            iteration+1,
        )

# %% [markdown]
# #### Run it:

# %%
update_networks(my_ndex, pfocr_figures_df)
# Out:
# attempt 1 of 4
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1249490__nihms5296f3.jpg / d8def56c-dec7-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1307498__nihms5498f3.jpg / 3996467d-df0d-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1307511__nihms2079f3.jpg / 4957b6d6-df34-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1351030__nihms2404f8.jpg / bc34e7af-de8d-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1352153__nihms-7536-0007.jpg / 4a7427d9-de8e-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1352320__nihms6852f1.jpg / f174c37f-def0-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1360222__nihms7040f9.jpg / d48f9e7a-deaa-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1360652__nihms5419f6.jpg / 6dc1d500-dece-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1424219__nihms-8396-0003.jpg / 80a5138e-deaa-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1434604__nihms-8487-0001.jpg / e0320bf0-df08-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1436036__nihms7964f12.jpg / 23844487-df06-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1458968__nihms-3923-0004.jpg / 7701d0c9-df1b-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1466347__nihms4561f2.jpg / 5154ce6e-dee9-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1479092__nihms-10426-0011.jpg / 45d9ea45-ded9-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1526464__nihms-10846-0008.jpg / fc823d75-defc-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1544360__nihms10600f7.jpg / d33c4ac4-df21-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1551980__nihms4840f1.jpg / 9eae984c-df0e-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1551980__nihms4840f3.jpg / ada71529-ded5-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1551980__nihms4840f4.jpg / ae610d25-df13-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1618798__nihms-12625-0002.jpg / 11831ec7-df1e-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1618798__nihms-12625-0003.jpg / 60e66a20-df12-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1679905__nihms-9845-0006.jpg / 30044ee4-df39-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1698952__nihms13324f4.jpg / f237a87a-ded7-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1705971__nihms-14550-0007.jpg / f423aa2b-debb-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1761117__nihms14873f1.jpg / 8e21168b-def8-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1761692__nihms15100f6.jpg / 927de764-ded0-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1762141__nihms-15247-0001.jpg / dbbc99f2-dec7-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1764624__nihms-13409-0001.jpg / c6cea16d-df11-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1769521__nihms3229f2.jpg / 2cdee215-df0b-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1779900__nihms15523f6.jpg / 8f71ecb2-dee0-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1780025__nihms-13355-0002.jpg / f5dc7433-deaf-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1781924__nihms14516f1.jpg / 0208d616-df2c-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1804097__nihms14446f7.jpg / 08897607-ded8-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1820632__nihms16167f1.jpg / 84e97b85-def1-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1820832__nihms18885f8.jpg / c59bda25-deba-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1820838__nihms13582f2.jpg / 7bc81243-df18-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1828071__nihms16392f12.jpg / 18851d7b-de9d-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1828071__nihms16392f1a.jpg / d5a528b0-df06-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1828071__nihms16392f2.jpg / 49841ebe-df04-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1828075__nihms-17843-0002.jpg / 98023ef5-dea7-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1828869__nihms-14552-0002.jpg / 2c04c4b5-deb8-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1828906__nihms15543f2.jpg / df8e26d0-df34-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1838573__nihms-12454-0001.jpg / 54fb6336-ded6-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1839882__nihms14908f9.jpg / 9a9c9f00-def9-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1839983__nihms16683f4.jpg / 9b7f2b94-de94-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1847591__nihms18592f1.jpg / 29faace5-de9c-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1850891__nihms19439f2a.jpg / 03c90e00-df10-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1851929__nihms18962f8.jpg / 561125b3-dee6-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1853294__nihms20074f10.jpg / 538ecab6-dec2-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1858678__nihms-20577-0002.jpg / 602c5b48-df0d-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1862519__nihms18021f1.jpg / 034bc815-dee0-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1866365__nihms15098f8.jpg / ea767232-deb1-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1868538__nihms20740f2.jpg / 14138847-de91-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1868540__nihms20764f1.jpg / 0b029725-df2e-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1876691__nihms20823f11.jpg / 80f9e514-df06-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1876696__nihms20793f1.jpg / 49518b00-df06-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1876750__nihms20399f2.jpg / 88829420-df09-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1876792__nihms-16041-0001.jpg / 2a19eec0-df0e-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1885837__halms122385f6.jpg / a5a29752-df08-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1885990__nihms20397f1.jpg / 97cf2633-df34-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1893009__nihms21039f9.jpg / df9d6c89-debe-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1894940__nihms19214f5.jpg / 6d2ac41e-ded9-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1905845__nihms21617f6.jpg / 2aeffcc9-df06-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1931516__nihms23229f3.jpg / d7c3c9fd-dede-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1934514__nihms20598f2.jpg / 3229b284-df07-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1934514__nihms20598f4.jpg / 4a11ead5-deb0-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1939976__nihms24352f1.jpg / 0bab4475-df07-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1939976__nihms24352f3.jpg / 123df998-df15-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1950120__nihms26639f7.jpg / 6355b603-dec0-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1950429__nihms23014f3.jpg / 0d4cb7a2-df0a-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1951533__nihms-770-f0014.jpg / 59b90a3a-df09-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1952230__nihms21045f1.jpg / 994f65d7-ded1-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1952537__nihms22688f2.jpg / c7d8a526-decc-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1955758__nihms27561f2.jpg / 4ec64276-df13-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1963413__nihms26729f1.jpg / d24df1ac-df07-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1963413__nihms26729f2.jpg / 17d7399b-ded6-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1963416__nihms26757f1.jpg / 98d7885d-deff-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1964795__nihms26012f5.jpg / bfff9411-dea1-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1974879__nihms25800f1.jpg / 3ca0d0f4-deaa-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1976272__nihms-27153-f0007.jpg / 646da687-dea1-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1976278__nihms-23911-f0008.jpg / c3dd40f3-df31-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1978064__nihms25712f4.jpg / 9c0eea59-dea3-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1986651__nihms-26871-f0001.jpg / ea0fb920-dee4-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1986710__nihms25811f1.jpg / d96706a1-dec6-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1987323__nihms28386f2.jpg / fe263b78-ded5-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1991338__nihms27480f1.jpg / d1df7c93-df00-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1991338__nihms27480f3.jpg / 094b8775-df1a-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1992444__nihms29760f3.jpg / 6d37e8b6-df11-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1992519__nihms29919f2.jpg / 0b667702-deb6-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1993849__nihms25825f7.jpg / 4395921c-deaf-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1993906__nihms21050f16.jpg / 1710a4af-df22-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1994114__nihms26978f4.jpg / ae66e561-debf-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1995559__nihms28624f3.jpg / 3d929ea0-de8f-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1995566__nihms21116f7.jpg / 68f614e0-dea1-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC1995599__nihms25729f2.jpg / c014cd30-df39-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2000447__nihms29533f1.jpg / d559ad41-decc-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2000831__nihms28507f3.jpg / 2e706871-df39-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2002522__nihms27266f2.jpg / dfc34011-df0f-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2013735__nihms-31670-f0004.jpg / 644ba508-df2e-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2034445__nihms-31678-f0001.jpg / d430795c-dea8-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2039920__nihms29873f2.jpg / 4abd97ff-deb4-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2039930__nihms-22413-f0007.jpg / 46bf6e9b-dee1-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2040031__nihms32178f1.jpg / b9f54539-debf-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2041936__nihms-29895-f0001.jpg / 52eb6604-deef-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2063509__nihms-31284-f0003.jpg / 410fc3dd-deaa-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2071927__nihms30932f2.jpg / 29e0be9a-df00-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2075101__nihms-30394-f0001.jpg / c9d5dde1-df08-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2077852__nihms32806f3.jpg / 53dbdb16-deac-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2077853__nihms20501f9.jpg / d8c48e3f-dead-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2078333__nihms31235f1.jpg / 607e523a-df15-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2080843__nihms-29652-f0003.jpg / b0722956-de90-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2082051__nihms30361f5.jpg / 719aa114-de8f-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2083698__nihms31045f6.jpg / 919688f6-deda-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2093951__nihms31050f9.jpg / ce01f589-ded0-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2094129__nihms33211f2.jpg / d3f21931-df14-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2097959__nihms33845f2.jpg / 023a8ada-df20-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2128044__nihms34367f2.jpg / 94ec2cfe-df38-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2134838__nihms-30692-f0001.jpg / a5c1ff6d-df30-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2134838__nihms-30692-f0002.jpg / deb8b1e7-df38-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2136409__nihms34093f7.jpg / a3d497f6-de9a-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2136409__nihms34093f8a.jpg / 19764563-de9b-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2136411__nihms21151f2.jpg / 64bdad28-decf-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2147684__nihms-35362-f0004.jpg / 511858d8-dead-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2153436__nihms35807f4.jpg / 9d911f8b-de8d-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2153443__nihms34878f8.jpg / 1e65de4b-dee9-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2156153__nihms31815f7.jpg / e18204a8-de91-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2169297__nihms33167f1.jpg / 75209dbe-df0a-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2174836__nihms30796f1.jpg / 6c2b226d-df08-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2174913__nihms36367f2.jpg / ef228d14-df09-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2180420__nihms35980f9.jpg / 2a2e2c8f-ded9-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2189984__nihms36804f7.jpg / 9e79c7b6-df20-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2192627__nihms35817f1.jpg / 1282bcc2-deeb-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2203613__nihms35403f10.jpg / 7763985b-def9-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2211634__nihms37175f3.jpg / c03aa8c2-de9e-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2214303__nihms37401f5.jpg / 7b1933bf-de8f-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2221774__nihms34078f1.jpg / 4fcea11a-de90-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2225477__nihms38124f1.jpg / 5888e0d1-df04-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2225482__nihms38139f9.jpg / a0b7b190-df1d-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2225532__nihms38141f1.jpg / 6a6aff2c-df31-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2228264__nihms38142f2.jpg / 879ef396-decb-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2228269__nihms38132f1.jpg / e117e11e-deef-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2231808__nihms-32008-f0001.jpg / 92a83be8-debf-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2233603__nihms37849f7.jpg / 6c2cfe36-dee0-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2233890__nihms38769f4.jpg / a8baf676-df0f-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2234035__nihms38624f7.jpg / 8623c543-decb-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2235195__nihms37999f1.jpg / f96a9e24-df16-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2238720__nihms23139f2.jpg / 4746ba69-ded1-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2246086__nihms37246f1.jpg / 5b3859e7-dee8-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2247407__nihms39909f2.jpg / 1bb98d79-deea-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2247407__nihms39909f3.jpg / 747bf9e6-df24-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2248324__nihms38119f17.jpg / 0ebcbb90-df0d-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2248324__nihms38119f8.jpg / 397bc6ec-df1d-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2248324__nihms38119f9.jpg / a4d78e00-df27-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2259386__nihms40621f1.jpg / f411ee49-dea4-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2265776__nihms-40937-f0007.jpg / 2eeb338c-df13-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2266095__nihms40435f2.jpg / a6d37c03-dec6-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2266688__nihms41216f1.jpg / 06f6fdca-dedd-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2267763__nihms-38923-f0002.jpg / fa549d0b-defe-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2268988__nihms36365f2.jpg / 508a5767-df07-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2268988__nihms36365f3.jpg / fdd587fa-de9e-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2270476__nihms21124f6.jpg / 4a8931b7-df0f-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2271030__nihms-40727-f0008.jpg / fbdca7b7-def4-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2271047__nihms41150f7.jpg / 63c96870-ded7-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2276649__nihms39366f8.jpg / ab84ee01-def9-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2276871__nihms41805f1.jpg / 4c8ecd72-deb7-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2277216__nihms-42153-f0004.jpg / d058a094-ded9-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2277498__nihms-43208-f0003.jpg / be7868b8-decf-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2277504__nihms-37907-f0008.jpg / 0725f3c4-dea1-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2278039__nihms43806f2.jpg / c971da8a-deb5-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2288618__nihms43701f7.jpg / ea1d6110-dea7-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2288663__nihms22628f6.jpg / 235affb7-df2d-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2289906__nihms-43596-f0001.jpg / 4cad236c-df34-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2291143__nihms-43292-f0004.jpg / 3262cc98-deaf-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2291143__nihms-43292-f0008.jpg / 87c7570d-de96-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2291295__nihms44279f1.jpg / eaba08e0-dec7-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2291295__nihms44279f2.jpg / a4af1aed-ded9-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2292467__nihms44358f6.jpg / 1860eb30-deab-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2292640__nihms44316f1.jpg / 30251bd5-defa-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2311419__nihms43224f1a.jpg / 94518f58-df1d-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2322867__nihms45365f2.jpg / 2985ac5a-debe-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2324067__nihms40586f1.jpg / 3a227ff6-def3-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2330263__nihms-41387-f0002.jpg / 652a8651-ded4-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2349095__nihms44963f2.jpg / a8d785b2-dea8-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2362144__nihms45939f6.jpg / 183d49d4-dec3-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2366099__nihms-44550-f0001.jpg / 53b5e2af-df09-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2366802__nihms-46660-f0004.jpg / 30076e6d-df37-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2367159__nihms-44669-f0009.jpg / 8e82de0e-defb-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2373983__nihms-47609-f0001.jpg / 2bd52436-df14-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2374695__nihms46978f1.jpg / b3caaa95-df07-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2377014__nihms45980f10.jpg / d11ef578-df0c-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2377356__nihms47975f2.jpg / c25c69fc-df08-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2386261__nihms47944f1.jpg / 74e8e10d-dee4-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2387053__nihms49842f2.jpg / a4df27b9-debb-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2394714__nihms43040f10.jpg / d9d39604-dee9-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2396493__nihms47079f1.jpg / eb48ca41-debe-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2396785__nihms37967f2.jpg / 0a6eecfc-deb5-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2398769__nihms47946f4.jpg / 234eaddf-dee4-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2405914__nihms-44887-f0004.jpg / c72f7876-df0c-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2405915__nihms-44878-f0008.jpg / e236f345-deaa-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2405926__nihms-44886-f0005.jpg / 5e02b937-decd-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2405945__nihms49388f1.jpg / 7d470de8-deef-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2408857__nihms49743f6.jpg / c0a25b87-deaf-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2410042__nihms39808f2.jpg / 7c687952-df0a-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2410298__nihms47417f1.jpg / 14872d81-df12-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2413267__nihms50555f1.jpg / 06aedd89-dec8-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2413330__nihms-49157-f0003.jpg / 6c05cb1d-dee4-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2423668__nihms48789f1.jpg / afe08272-df08-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2430411__nihms52909f2.jpg / afbe9039-dee5-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2430594__nihms-53405-f0001.jpg / 6f1bfd3b-df34-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2432088__nihms51274f1.jpg / 5fde48e7-deed-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2432088__nihms51274f3.jpg / 580ec5d8-deed-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2435382__nihms32991f11.jpg / 36e7495b-dedc-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2440498__nihms46636f1.jpg / 00b83863-df1d-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2442161__halms287635f8.jpg / a3c2b342-de99-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2442829__nihms51320f1.jpg / ad9a8882-dec9-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2442829__nihms51320f2.jpg / 7b78c8dc-df12-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2443634__nihms52312f1.jpg / b53becb5-df12-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2443745__nihms52324f1.jpg / a74e2e95-df14-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2446602__nihms55687f1.jpg / 0f618e41-de9b-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2455793__nihms56346f1.jpg / 2fe601d5-ded3-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2467395__nihms50544f2.jpg / 3af53aa3-df32-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2467395__nihms50544f4.jpg / 2c6c6e34-df2c-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2474812__nihms52369f1.jpg / 3348c804-dea1-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2476215__nihms54344f3.jpg / ae6fa8f3-deed-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2484121__nihms57731f2.jpg / 276daff2-de93-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2486832__nihms55797f3.jpg / c5fb9128-df05-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2491722__nihms57217f4.jpg / f60d813b-dead-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2491722__nihms57217f6.jpg / 45009601-dee3-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2493614__nihms-56895-f0002.jpg / 3a372605-deb9-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2494582__nihms55746f1.jpg / 0e37de76-df0e-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2494613__ukmss-2052-f0001.jpg / c072108e-de97-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2494613__ukmss-2052-f0003.jpg / 6be2eba2-de8d-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2494876__nihms55489f8.jpg / 8def6d2f-defa-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2504760__nihms56027f1.jpg / 4b03667c-decc-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2515553__nihms56021f1.jpg / a01c3d2a-dec5-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2516940__nihms48003f2.jpg / 9889e048-deb9-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2517052__nihms53910f3.jpg / d0db6e22-dec0-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2517145__nihms54908f1.jpg / 233fb492-deac-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2519122__nihms-60222-f0001.jpg / fa38c8ca-df04-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2519798__nihms54897f5.jpg / c832affb-dec5-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2522268__nihms56475f1.jpg / 8c5be0ae-df15-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2527618__nihms-47540-f0005.jpg / 049e1dc4-ded6-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2531163__nihms65923f3.jpg / b49984c0-de93-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2532600__nihms56058f2.jpg / 37553943-df24-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2533280__nihms64392f6.jpg / 9d281135-df14-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2542903__nihms62958f6.jpg / b1a9f55d-def9-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2543934__nihms65813f2.jpg / 84cb896a-df15-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2543934__nihms65813f4.jpg / 8c0068ec-df31-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2543934__nihms65813f5.jpg / 1749da4c-df13-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2547491__nihms60349f1.jpg / 7080cdf6-dece-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2548299__nihms67577f7.jpg / 4e687de8-dee1-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2553363__nihms60357f1.jpg / 02a41b9a-def3-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2553363__nihms60357f2.jpg / b71be9cb-df0d-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2553363__nihms60357f5.jpg / 508a140b-de8e-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2553712__nihms62811f1.jpg / 61f046d9-df17-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2556175__nihms61825f3.jpg / af74cf24-df10-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2556249__nihms62538f2.jpg / 575fc33b-df2c-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2556276__nihms-49618-f0001.jpg / 79faf969-df06-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2556850__nihms65948f1.jpg / d5cbee65-deff-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2561288__nihms54511f1.jpg / 413703b9-df0b-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2561962__nihms-52055-f0001.jpg / 99b078fa-dece-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2562038__nihms68083f2.jpg / 3ffd42d2-dec4-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2562790__nihms26194f2.jpg / 371dada6-deb5-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2563957__nihms-69383-f0001.jpg / 85738669-df06-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2566585__nihms70789f1.jpg / f03fbe13-ded9-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2566739__halms250143f2.jpg / 39f9fd17-dedb-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2566956__nihms16677f6.jpg / 15532a2d-df2f-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2567114__nihms-66000-f0007.jpg / 707ee9c7-deaf-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2570700__nihms67164f1.jpg / 9e876274-deb9-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2570700__nihms67164f2.jpg / da2ba8c6-dee6-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2570709__nihms73332f1.jpg / 9dbcb9bc-defb-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2570709__nihms73332f2.jpg / 8cb49d45-df0c-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2572856__nihms53518f1.jpg / fb84b0c7-deb7-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2572865__nihms-71866-f0001.jpg / f22b6e7d-deb9-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2574011__nihms57373f1.jpg / 11be7270-deb2-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2574595__nihms64343f10.jpg / ddfaefcd-df27-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2574638__nihms64344f8.jpg / b229bc1f-dec3-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2574672__nihms59361f2.jpg / 24d36e0f-df13-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2574729__nihms-54192-f0002.jpg / 1a64a13e-de94-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2574814__nihms-65799-f0027.jpg / 0e39a8c2-df32-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2574839__nihms71471f1.jpg / 0e257f91-deca-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2575803__nihms69787f1.jpg / 2015d4cc-df0a-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2575845__nihms-73092-f0001.jpg / 982a9f6e-ded2-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2577004__nihms72309f1.jpg / 3d03da9e-deb9-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2577227__nihms27793f7.jpg / 04f457b7-deaa-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2577230__nihms-70879-f0001.jpg / 74e5d9fc-df36-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2578836__nihms63415f7.jpg / 3ab35690-df2f-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2578840__nihms69505f8.jpg / 4a863dad-df0a-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2579766__nihms72466f3.jpg / ee20a434-df22-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2579774__nihms76115f4.jpg / 3d4713d5-df2a-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2580829__nihms75391f8.jpg / 621341ff-deb4-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2581748__nihms-77271-f0002.jpg / afa95cca-decf-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2581798__nihms76816f3.jpg / ffda8df5-dec8-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2582216__nihms76677f1.jpg / 8630d75a-df10-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2583327__nihms60343f10.jpg / fa17af20-debe-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2583357__nihms-77201-f0001.jpg / 16305cd6-df05-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2583357__nihms-77201-f0003.jpg / 265aeade-df0e-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2583931__nihms64264f1.jpg / b713f65c-de9a-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2584165__nihms-71679-f0002.jpg / 91d11a74-df02-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2585609__nihms64538f2.jpg / da1dfe6f-df14-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2585776__nihms70500f6.jpg / 7cb71c9c-de95-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2585776__nihms70500f8.jpg / c2b05fc2-deef-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2586109__nihms-76803-f0001.jpg / 7d7a95f7-def9-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2586899__nihms76167f4.jpg / ccf221d6-deec-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2586935__nihms74892f4.jpg / a3f0a7ad-df1b-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2586935__nihms74892f5.jpg / 119c7f75-df09-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2587085__nihms56291f1.jpg / 4876d916-defa-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2587159__nihms43773f3.jpg / 211358e9-de99-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2587303__nihms54146f1.jpg / 6e17036d-deda-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2590753__nihms59069f7.jpg / 3ce5362d-dedb-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2590784__nihms70503f1.jpg / 712df403-dec2-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2593077__nihms64601f2.jpg / 6cefa42b-deb6-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2593475__nihms-79781-f0001.jpg / fba68566-df0b-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2593475__nihms-79781-f0002.jpg / fe362d53-df12-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2594010__nihms66966f2.jpg / 68957245-df00-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2596629__nihms-78103-f0006.jpg / 9cc4d33d-def5-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2596750__nihms70476f8.jpg / caad6d9b-df12-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2596919__nihms71140f2.jpg / d7e028d8-deb5-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2597184__nihms-81185-f0002.jpg / 6da1e56a-ded8-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2597223__nihms80655f1.jpg / fa42812c-dec4-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2597345__nihms79152f5.jpg / 1eef99a7-df2e-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2597498__nihms65853f1.jpg / 5c0feb23-de92-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2597498__nihms65853f2.jpg / 4d4eaa67-ded6-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2597498__nihms65853f4.jpg / 3518eb53-df04-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2597703__nihms-77115-f0001.jpg / e8288b7d-def0-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2597781__nihms-74735-f0005.jpg / fa63ee8b-dea3-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2597805__nihms34942f8.jpg / 10541673-df2d-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2597811__nihms37181f1.jpg / 09837af5-de9b-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2597811__nihms37181f2.jpg / 095da6c1-dee9-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2597859__nihms58894f1.jpg / 3be9512d-defd-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2600414__nihms-81117-f0001.jpg / e7150af1-df13-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2601595__nihms-81428-f0002.jpg / 1eb5da30-de9c-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2601595__nihms-81428-f0003.jpg / 7b8bdd78-deb2-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2601639__nihms59183f1.jpg / 6eaec763-de96-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2601664__nihms-65993-f0001.jpg / f70aa16d-de8f-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2601665__nihms-49069-f0002.jpg / 4098d240-df0c-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC2603136__nihms-81890-f0005.jpg / c403c354-deb1-11ea-99da-0ac135e8bacf
# ...
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5902181__nihms956838f1.jpg / ada7692e-df0d-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5903427__nihms956825f1.jpg / 1b391d12-df10-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5903677__nihms953569f3.jpg / f0a36fc0-df28-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5903986__nihms911251f1.jpg / e72e15f1-df0c-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5905346__nihms923692f1.jpg / 4e55f233-df04-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5908737__nihms911052f1.jpg / fcfb4964-df17-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5909840__nihms958525f2.jpg / d6cf63f6-dea4-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5910217__nihms944011f2.jpg / ca76a2f0-df0e-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5910271__nihms918148f2.jpg / 28ac959c-ded9-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5910288__nihms939838f3.jpg / 57f489b8-ded7-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5912962__nihms923467f1.jpg / 030e381e-df07-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5912981__nihms940071f1.jpg / 398ae9f8-df34-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5913738__nihms958771f2.jpg / 41bb5d6a-df05-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5913738__nihms958771f3.jpg / c3bf3427-dea1-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5916807__nihms958976f7.jpg / 8d8f2fcb-def0-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5918238__nihms915201f3.jpg / 70e10a0e-deb3-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5918687__nihms944405f5.jpg / e7f3b43f-deb0-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5920772__nihms916241f3.jpg / 972b4b8b-de9d-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5921900__nihms959796f2.jpg / d559d953-de95-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5921923__nihms933183f1.jpg / 887838b9-dead-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5926825__nihms940411f1.jpg / 4370b753-dec7-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5927358__nihms961561f1.jpg / d71144e0-dec8-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5927358__nihms961561f2.jpg / cca880b4-dec5-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5927358__nihms961561f3.jpg / 9fe72014-dec1-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5927601__nihms961193f2.jpg / ebdb6aaf-df29-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5928506__nihms961045f8.jpg / 108be656-decc-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5929146__nihms884040f1.jpg / 01c2556a-ded3-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5929164__nihms872185f5.jpg / 331559f9-de92-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5930388__nihms961709f2.jpg / f4d30fe9-deae-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5930388__nihms961709f5.jpg / 58dcc921-deb6-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5932236__nihms941942f4.jpg / 2df1028d-df18-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5932261__nihms960111f7.jpg / 308c1289-df08-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5935233__emss-76729-f003.jpg / 7b03017a-de91-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5935570__nihms926175f5.jpg / cdbb0a96-df31-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5936084__nihms962717f1.jpg / 8c0caac9-df1c-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5937133__nihms962129f1.jpg / b6d7fd9c-df1f-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5937267__nihms961117f1.jpg / ad85e21d-dee9-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5937716__nihms961952f3.jpg / c578bef8-df25-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5938095__nihms946052f8.jpg / ed7ac17a-deea-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5940532__nihms951022f2.jpg / 966cfea5-df04-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5940532__nihms951022f3.jpg / 15e4cd03-debe-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5942188__nihms961201f1.jpg / 1cf702d7-ded2-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5943174__nihms949200f1.jpg / 9e98f129-df37-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5943638__nihms964864f1.jpg / 49907622-dec1-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5946314__nihms457701f1.jpg / 2e39a998-df06-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5946314__nihms457701f3.jpg / a8f2fa13-df38-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5948169__nihms956952f8.jpg / 11276f3e-dec2-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5949249__nihms919897f1.jpg / 741ecc15-dedf-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5949255__nihms925265f3.jpg / 695d0d18-deee-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5949883__nihms937639f2.jpg / de6f0221-dee7-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5951297__nihms802219f4.jpg / fd4c54aa-de96-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5951620__nihms775729f1.jpg / 0fddf6a1-deab-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5951756__nihms954468f4.jpg / b86196c4-df12-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5953846__nihms963973f8.jpg / b4317ac2-dee5-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5954996__nihms958779f7.jpg / c4ef14af-df28-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5955724__nihms937019f1.jpg / afbe3d88-dec7-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5955808__nihms935542f1.jpg / f6d64eb1-de93-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5957297__nihms961982f3.jpg / 3a8c9689-df24-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5957297__nihms961982f4.jpg / 09548ff3-df17-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5957514__nihms916201f1.jpg / d47eead0-df26-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5958547__nihms962393f1.jpg / 854c0801-df0e-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5959760__nihms945416f2.jpg / 616914c2-ded8-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5961736__nihms964503f1.jpg / 6521ce98-df0b-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5961736__nihms964503f2.jpg / 6c911e15-df0d-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5961736__nihms964503f3.jpg / 7e81ae76-df10-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5961736__nihms964503f4.jpg / 4d7db003-dede-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5962346__nihms923919f1.jpg / 8bec2211-df05-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5963710__nihms942920f7.jpg / 139117f9-df13-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5963715__nihms959388f3.jpg / caee22ff-def1-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5963988__nihms935410f3.jpg / d64c4f73-df0f-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5964014__nihms951903f7.jpg / 44464d59-df10-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5964334__nihms860297f6.jpg / 0785ced9-dec3-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5964982__nihms967212f2.jpg / 4d4cef25-ded1-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5965678__nihms954901f4.jpg / 78749802-dec2-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5965688__nihms966637f8.jpg / 998ced43-de93-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5971139__nihms950730f4.jpg / 7f2155b6-deb1-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5972548__nihms969201f2.jpg / 155b8f84-decf-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5973839__nihms958963f1.jpg / e513112b-deaa-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5973839__nihms958963f3.jpg / 2127291f-deb6-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5973841__nihms962224f2.jpg / b8ed03a1-df11-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5975185__nihms958103f8.jpg / 2302384f-df05-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC5975367__nihms966579f3.jpg / cf19c8ac-df07-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6357950__rg.2019180054.fig2.jpg / 6079e99c-dee9-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6844627__nihms-994467-f0004.jpg / 0ac3a4fa-decc-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6853184__nihms-1057696-f0005.jpg / 2765c323-df11-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6855178__nihms-1058736-f0001.jpg / fe8ffb77-debf-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6857536__nihms-1057274-f0002.jpg / 55b97e74-df0d-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6858087__nihms-1004504-f0001.jpg / 6874fdfe-df1b-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6858495__nihms-1042549-f0004.jpg / 8cb498b5-def9-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6858495__nihms-1042549-f0008.jpg / ef1af4ca-dea6-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6858516__nihms-1054030-f0001.jpg / 3f9d0531-df0f-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6858516__nihms-1054030-f0003.jpg / 71282ee3-debf-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6858516__nihms-1054030-f0004.jpg / 3d9cf258-dec9-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6858516__nihms-1054030-f0005.jpg / 5574620d-de97-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6858516__nihms-1054030-f0006.jpg / 1051244c-dea3-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6858840__nihms-1059171-f0001.jpg / 1a2370cf-dead-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6871180__nihms-1058320-f0003.jpg / 504074dc-dec0-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6876298__nihms-1059361-f0002.jpg / 4dd07431-def2-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6880928__nihms-1059788-f0001.jpg / f094da35-dee7-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6886244__nihms-1058852-f0001.jpg / c10c28d6-df18-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6891142__nihms-1526199-f0004.jpg / 3865bd94-df0a-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6894370__nihms-1060417-f0003.jpg / 4e16266e-de91-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6894939__EMS84579-f002.jpg / 1f0cccba-df0e-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6901278__nihms-1058325-f0003.jpg / 4ca79895-deaa-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6902869__nihms-1059519-f0001.jpg / 56ee9a3c-df1b-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6902872__nihms-1060876-f0001.jpg / 7292c4e3-df20-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6904929__nihms-1507459-f0002.jpg / 888ca961-dee8-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6905465__nihms-276620-f0002.jpg / c4f53948-de95-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6907743__nihms-1062023-f0001.jpg / 27dc981e-ded5-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6907743__nihms-1062023-f0003.jpg / c821f910-dee8-11ea-99da-0ac135e8bacf
# missing_column_name: publication_year not found in pfocr_figures_row for PMC6908429__nihms-1057672-f0004.jpg / 329eef20-decd-11ea-99da-0ac135e8bacf
# we have completed all the networks
# 0

# %%
update_networks(my_ndex, (pfocr_figures_df[
    pfocr_figures_df["network_id"].notnull()
]))
